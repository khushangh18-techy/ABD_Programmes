# %%
import pyspark
import os
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
filepath = r'C:\Users\MSIS\Downloads\Khushan_BDA\ABD\SparkSession\sf-fire-calls.csv'

# %%
def create_sparkSession():
    spark=SparkSession.builder.appName('Fire Example').getOrCreate()
    return spark

# %%
def create_dataframe(spark,filepath):
    df=spark.read.csv(filepath,header=True,inferSchema=True)
    df1=df.select('CallType','CallDate','City','Zipcode','Neighborhood','Delay')
    return df1

# %%
def clean_dataset(df):
    df1=df.withColumn('Date',to_date(col('CallDate'), 'MM/dd/yyyy')).drop('CallDate')
    df2=df1.withColumn('Year',year(col('Date')))\
    .withColumn('Month',month(col('Date')))\
    .withColumn('week',weekofyear(col('Date')))
    return df2

# %%
spark=create_sparkSession()
df=create_dataframe(spark,filepath)
df=clean_dataset(df)
df.printSchema()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 spark=create_sparkSession()
#       2 df=create_dataframe(spark,filepath)
#       3 df=clean_dataset(df)
#       4 df.printSchema()
#
# NameError: name 'create_sparkSession' is not defined
